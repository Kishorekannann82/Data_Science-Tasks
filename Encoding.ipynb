# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("customer_churn_dataset-training-master.csv")
test=pd.read_csv("customer_churn_dataset-testing-master.csv")

# %%
train.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
test.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
train.shape
# Out:
# (440833, 12)

# %%
test.shape
# Out:
# (64374, 12)

# %%
train.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 40.4+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64374 entries, 0 to 64373
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         64374 non-null  int64
#  1   Age                64374 non-null  int64
#  2   Gender             64374 non-null  object
#  3   Tenure             64374 non-null  int64
#  4   Usage Frequency    64374 non-null  int64
#  5   Support Calls      64374 non-null  int64
#  6   Payment Delay      64374 non-null  int64
#  7   Subscription Type  64374 non-null  object
#  8   Contract Length    64374 non-null  object
#  9   Total Spend        64374 non-null  int64
#  10  Last Interaction   64374 non-null  int64
#  11  Churn              64374 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 5.9+ MB

# %%
train.describe()
# Out:
#           CustomerID            Age         Tenure  Usage Frequency  \
# count  440832.000000  440832.000000  440832.000000    440832.000000
# mean   225398.667955      39.373153      31.256336        15.807494
# std    129531.918550      12.442369      17.255727         8.586242
# min         2.000000      18.000000       1.000000         1.000000
# 25%    113621.750000      29.000000      16.000000         9.000000
# 50%    226125.500000      39.000000      32.000000        16.000000
# 75%    337739.250000      48.000000      46.000000        23.000000
# max    449999.000000      65.000000      60.000000        30.000000
#
#        Support Calls  Payment Delay    Total Spend  Last Interaction  \
# count  440832.000000  440832.000000  440832.000000     440832.000000
# mean        3.604437      12.965722     631.616223         14.480868
# std         3.070218       8.258063     240.803001          8.596208
# min         0.000000       0.000000     100.000000          1.000000
# ...

# %%
train['Contract Length'].value_counts()
# Out:
# Contract Length
# Annual       177198
# Quarterly    176530
# Monthly       87104
# Name: count, dtype: int64

# %%
train["Subscription Type"].value_counts()
# Out:
# Subscription Type
# Standard    149128
# Premium     148678
# Basic       143026
# Name: count, dtype: int64

# %%
train['Gender'].value_counts()
# Out:
# Gender
# Male      250252
# Female    190580
# Name: count, dtype: int64

# %%
train.dtypes
# Out:
# CustomerID           float64
# Age                  float64
# Gender                object
# Tenure               float64
# Usage Frequency      float64
# Support Calls        float64
# Payment Delay        float64
# Subscription Type     object
# Contract Length       object
# Total Spend          float64
# Last Interaction     float64
# Churn                float64
# dtype: object

# %%
## task-3 :Classify each categorical column as:Binary,Nominal
for col in ['Gender', 'Subscription Type', 'Contract Length']:
    print(col, ":", train[col].unique())
# Out:
# Gender : ['Female' 'Male' nan]
# Subscription Type : ['Standard' 'Basic' 'Premium' nan]
# Contract Length : ['Annual' 'Monthly' 'Quarterly' nan]

# %%
cat_cols=['Gender','Subscription Type','Contract Length']
train=train.dropna(subset=cat_cols)

# %%
## Task-2 Categorical columns
cat_cols=train.select_dtypes(include=['object']).columns
print("Categorical Columns")
print(list(cat_cols))
# Out:
# Categorical Columns
# ['Gender', 'Subscription Type', 'Contract Length']

# %%
train['Gender'].unique() #->Binary Because it has only male and female
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
train['Subscription Type'].unique()
# Out:
# array(['Standard', 'Basic', 'Premium'], dtype=object)

# %%
train['Contract Length'].unique()
# Out:
# array(['Annual', 'Monthly', 'Quarterly'], dtype=object)

# %%
print("Binary Columns:")
print("Gender")
print("---------------------")
print("Nominal Column:")
print("Subscription Type")
print("Contract Length")
print("-------------------------")
# Out:
# Binary Columns:
# Gender
# ---------------------
# Nominal Column:
# Subscription Type
# Contract Length
# -------------------------

# %%
## Task 4
## Apply Label Encoding to all binary categorical columns.
from sklearn.preprocessing import LabelEncoder
binary_col=['Gender']
le=LabelEncoder()
train['Gender_le']=le.fit_transform(train['Gender'])

# %%
test=test.dropna(subset=cat_cols)

# %%
mapping={"Male":1,"Female":0}
test["Gender"]=test["Gender"].map(mapping)

# %%
train['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
## Task 5
## Apply Label Encoding to one nominal categorical column.
le=LabelEncoder()
train['Subscription Type']=le.fit_transform(train['Subscription Type'])

# %%
train['Subscription Type'].unique()
# Out:
# array([2, 0, 1])

# %%
print(le.classes_)
# Out:
# ['Basic' 'Premium' 'Standard']

# %%
test['Subscription Type'] = le.transform(test['Subscription Type'])

# %%
test['Subscription Type'].unique()
# Out:
# array([0, 2, 1])

# %%
## Task 6
## Apply One-Hot Encoding to all nominal categorical columns.
nominal_cols=['Subscription Type','Contract Length']
train=pd.get_dummies(train,columns=nominal_cols,drop_first=True)
test=pd.get_dummies(test,columns=nominal_cols,drop_first=True)

# %%
train.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Total Spend', 'Last Interaction',
#        'Churn', 'Gender_le', 'Subscription Type_1', 'Subscription Type_2',
#        'Contract Length_Monthly', 'Contract Length_Quarterly'],
#       dtype='object')

# %%
train.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay  Total Spend  Last Interaction  Churn  Gender_le  \
# 0           18.0        932.0              17.0    1.0          0
# 1            8.0        557.0               6.0    1.0          0
# 2           18.0        185.0               3.0    1.0          0
# 3            7.0        396.0              29.0    1.0          1
# 4            8.0        617.0              20.0    1.0          1
#
#    Subscription Type_1  Subscription Type_2  Contract Length_Monthly  \
# 0                False                 True                    False
# ...

# %%
## Task 7
## Apply One-Hot Encoding to one binary column and compare with Label Encoding.
binary_col='Gender'
gender_ohe=pd.get_dummies(train['Gender'],prefix='Gender',drop_first=True)
train = pd.concat([train, gender_ohe], axis=1)

# %%
train.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay  Total Spend  Last Interaction  Churn  Gender_le  \
# 0           18.0        932.0              17.0    1.0          0
# 1            8.0        557.0               6.0    1.0          0
# 2           18.0        185.0               3.0    1.0          0
# 3            7.0        396.0              29.0    1.0          1
# 4            8.0        617.0              20.0    1.0          1
#
#    Subscription Type_1  Subscription Type_2  Contract Length_Monthly  \
# 0                False                 True                    False
# ...

# %%
train[['Gender','Gender_le','Gender_Male']].head()
# Out:
#    Gender  Gender_le  Gender_Male
# 0  Female          0        False
# 1  Female          0        False
# 2  Female          0        False
# 3    Male          1         True
# 4    Male          1         True
